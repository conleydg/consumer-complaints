# %%
# %matplotlib inline

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import datetime

# %%
consumer_complaints =  pd.read_csv('complaints_dec_2014.csv')

# %%
date_series = consumer_complaints.pop('Date received')

# %%
consumer_complaints.index = pd.to_datetime(date_series, format='%m/%d/%Y')

# %%
consumer_complaints['weekday'] = consumer_complaints.index.weekday

# %%
consumer_complaints['day'] = consumer_complaints.index.weekday()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-29441eb9df0f> in <module>()
# ----> 1 consumer_complaints['day'] = consumer_complaints.index.weekday()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
grouped = consumer_complaints.groupby(['weekday', 'date']).count()

# %%
grouped = grouped[['Complaint ID']]

# %%
grouped_day = consumer_complaints.groupby(['weekday'])

# %%
grouped.loc[grouped.groups['weekday']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-f2fa5d17991f> in <module>()
# ----> 1 grouped.loc[grouped.groups['weekday']]
#
# /Users/David/.direnv/python-3.5.1/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2667             if name in self._info_axis:
#    2668                 return self[name]
# -> 2669             return object.__getattribute__(self, name)
#    2670
#    2671     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'groups'

# %%
grouped
# Out:
#                     Complaint ID
# weekday date
# 0       2014-12-01           474
#         2014-12-08           526
#         2014-12-15           475
#         2014-12-22           537
#         2014-12-29           532
# 1       2014-12-02           516
#         2014-12-09           503
#         2014-12-16           510
#         2014-12-23           501
#         2014-12-30           550
# 2       2014-12-03           494
#         2014-12-10           570
#         2014-12-17           539
#         2014-12-24           315
#         2014-12-31           371
# 3       2014-12-04           571
#         2014-12-11           484
#         2014-12-18           527
#         2014-12-25            52
# 4       2014-12-05           426
#         2014-12-12           428
#         2014-12-19           363
#         2014-12-26           229
# 5       2014-12-06           147
#         2014-12-13           144
#         2014-12-20           148
#         2014-12-27           104
# ...

# %%
grouped_day.head()
# Out:
#                Complaint ID                  Product  \
# Date received
# 2014-12-31          1177167          Debt collection
# 2014-12-31          1177166          Debt collection
# 2014-12-31          1177165          Debt collection
# 2014-12-31          1177164          Debt collection
# 2014-12-31          1177163          Debt collection
# 2014-12-30          1175111              Credit card
# 2014-12-30          1175107            Consumer loan
# 2014-12-30          1175100             Prepaid card
# 2014-12-30          1175099          Debt collection
# 2014-12-30          1175097              Credit card
# 2014-12-29          1172437         Credit reporting
# 2014-12-29          1177539            Consumer loan
# 2014-12-29          1176340            Consumer loan
# 2014-12-29          1176318  Bank account or service
# 2014-12-29          1176314                 Mortgage
# 2014-12-28          1172317         Credit reporting
# ...

# %%
date_and_product = consumer_complaints[['Product', 'weekday']]

# %%
count_by_weekday = date_and_product['weekday'].value_counts()

# %%
count_by_weekday
# Out:
# 1    2580
# 0    2544
# 2    2289
# 3    1634
# 4    1446
# 5     543
# 6     507
# Name: weekday, dtype: int64
